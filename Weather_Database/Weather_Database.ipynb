# %%
#Import dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

from citipy import citipy

# %%
#Create a set of 2,000 random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)

# %%
coordinates = list(lat_lngs)

cities = []
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    if city not in cities:
        cities.append(city)

len(cities)
# Out:
# 778

# %%
#Import dependencies
import requests
from config import weather_api_key

url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
city_data = []

print("Beginning Data Retrieval     ")
print("-----------------------------")

record_count = 1
set_count = 1

for i, city in enumerate(cities):
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    
    city_url = url + "&q=" + city.replace(" ","+")
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    record_count += 1
    
    try:
        city_weather = requests.get(city_url).json()
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_description = city_weather['weather'][0]['description']
        
        city_data.append({'City': city.title(),
                          'Country': city_country,
                          'Lat': city_lat,
                          'Lng': city_lng,
                          'Max Temp': city_max_temp,
                          'Humidity': city_humidity,
                          'Cloudiness': city_clouds,
                          'Wind Speed': city_wind,
                          'Current Description': city_description})
    except:
        print("City not found. Skipping...")
        pass

print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | vaini
# Processing Record 2 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 3 of Set 1 | hilo
# Processing Record 4 of Set 1 | tiksi
# Processing Record 5 of Set 1 | chuy
# Processing Record 6 of Set 1 | ushuaia
# Processing Record 7 of Set 1 | bengkulu
# Processing Record 8 of Set 1 | lebu
# Processing Record 9 of Set 1 | butaritari
# Processing Record 10 of Set 1 | mahebourg
# Processing Record 11 of Set 1 | bintulu
# Processing Record 12 of Set 1 | ponta do sol
# Processing Record 13 of Set 1 | tuktoyaktuk
# Processing Record 14 of Set 1 | kudahuvadhoo
# Processing Record 15 of Set 1 | arraial do cabo
# Processing Record 16 of Set 1 | henties bay
# Processing Record 17 of Set 1 | lashio
# Processing Record 18 of Set 1 | punta arenas
# Processing Record 19 of Set 1 | yellowknife
# Processing Record 20 of Set 1 | nantucket
# Processing Record 21 of Set 1 | ribeira grande
# Processing Record 22 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 23 of Set 1 | umzimvubu
# City not found. Skipping...
# Processing Record 24 of Set 1 | moussoro
# Processing Record 25 of Set 1 | erdaojiang
# Processing Record 26 of Set 1 | verkhnedneprovskiy
# Processing Record 27 of Set 1 | borovskoy
# Processing Record 28 of Set 1 | tasiilaq
# Processing Record 29 of Set 1 | olga
# Processing Record 30 of Set 1 | bluff
# Processing Record 31 of Set 1 | port alfred
# Processing Record 32 of Set 1 | ortakoy
# Processing Record 33 of Set 1 | ijaki
# City not found. Skipping...
# Processing Record 34 of Set 1 | rikitea
# Processing Record 35 of Set 1 | qaanaaq
# Processing Record 36 of Set 1 | jamestown
# Processing Record 37 of Set 1 | hithadhoo
# Processing Record 38 of Set 1 | kandrian
# Processing Record 39 of Set 1 | saint-alexandre
# Processing Record 40 of Set 1 | pevek
# Processing Record 41 of Set 1 | victoria
# Processing Record 42 of Set 1 | kamaishi
# Processing Record 43 of Set 1 | cape town
# Processing Record 44 of Set 1 | mar del plata
# Processing Record 45 of Set 1 | medzilaborce
# Processing Record 46 of Set 1 | upernavik
# Processing Record 47 of Set 1 | ukiah
# Processing Record 48 of Set 1 | tikapur
# Processing Record 49 of Set 1 | rabaul
# Processing Record 50 of Set 1 | ryotsu
# Processing Record 1 of Set 2 | avarua
# Processing Record 2 of Set 2 | audru
# Processing Record 3 of Set 2 | nemuro
# Processing Record 4 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 5 of Set 2 | thinadhoo
# Processing Record 6 of Set 2 | bilma
# Processing Record 7 of Set 2 | mataura
# Processing Record 8 of Set 2 | wajima
# Processing Record 9 of Set 2 | lake havasu city
# Processing Record 10 of Set 2 | torbay
# Processing Record 11 of Set 2 | omsukchan
# Processing Record 12 of Set 2 | sergeyevka
# Processing Record 13 of Set 2 | saint george
# Processing Record 14 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 15 of Set 2 | khatanga
# Processing Record 16 of Set 2 | busselton
# Processing Record 17 of Set 2 | dikson
# Processing Record 18 of Set 2 | laguna
# Processing Record 19 of Set 2 | ust-nera
# Processing Record 20 of Set 2 | nikolskoye
# Processing Record 21 of Set 2 | zambezi
# Processing Record 22 of Set 2 | talnakh
# Processing Record 23 of Set 2 | kamiichi
# Processing Record 24 of Set 2 | new norfolk
# Processing Record 25 of Set 2 | aksu
# Processing Record 26 of Set 2 | albany
# Processing Record 27 of Set 2 | provideniya
# Processing Record 28 of Set 2 | port lincoln
# Processing Record 29 of Set 2 | ancud
# Processing Record 30 of Set 2 | cherskiy
# Processing Record 31 of Set 2 | kruisfontein
# Processing Record 32 of Set 2 | srednekolymsk
# Processing Record 33 of Set 2 | atuona
# Processing Record 34 of Set 2 | stabat
# Processing Record 35 of Set 2 | hobart
# Processing Record 36 of Set 2 | kailua
# Processing Record 37 of Set 2 | dahanu
# Processing Record 38 of Set 2 | vilcun
# Processing Record 39 of Set 2 | vanderhoof
# Processing Record 40 of Set 2 | sorland
# Processing Record 41 of Set 2 | lagoa
# Processing Record 42 of Set 2 | luderitz
# Processing Record 43 of Set 2 | margate
# Processing Record 44 of Set 2 | vardo
# Processing Record 45 of Set 2 | narsaq
# Processing Record 46 of Set 2 | sao filipe
# Processing Record 47 of Set 2 | tumannyy
# City not found. Skipping...
# Processing Record 48 of Set 2 | saint-philippe
# Processing Record 49 of Set 2 | klaksvik
# Processing Record 50 of Set 2 | ishigaki
# Processing Record 1 of Set 3 | indiaroba
# Processing Record 2 of Set 3 | meulaboh
# Processing Record 3 of Set 3 | hobyo
# Processing Record 4 of Set 3 | san quintin
# Processing Record 5 of Set 3 | houston
# Processing Record 6 of Set 3 | pitimbu
# Processing Record 7 of Set 3 | dicabisagan
# Processing Record 8 of Set 3 | saldanha
# Processing Record 9 of Set 3 | east london
# Processing Record 10 of Set 3 | padang
# Processing Record 11 of Set 3 | kawalu
# Processing Record 12 of Set 3 | bolungarvik
# City not found. Skipping...
# Processing Record 13 of Set 3 | airai
# Processing Record 14 of Set 3 | bar harbor
# Processing Record 15 of Set 3 | tual
# Processing Record 16 of Set 3 | saint-georges
# Processing Record 17 of Set 3 | taoudenni
# Processing Record 18 of Set 3 | sanok
# Processing Record 19 of Set 3 | castro
# Processing Record 20 of Set 3 | brainerd
# Processing Record 21 of Set 3 | tigil
# Processing Record 22 of Set 3 | chagda
# City not found. Skipping...
# Processing Record 23 of Set 3 | ngunguru
# Processing Record 24 of Set 3 | hambantota
# Processing Record 25 of Set 3 | nuuk
# Processing Record 26 of Set 3 | lolua
# City not found. Skipping...
# Processing Record 27 of Set 3 | sao joao da barra
# Processing Record 28 of Set 3 | aguimes
# Processing Record 29 of Set 3 | peniche
# Processing Record 30 of Set 3 | bredasdorp
# Processing Record 31 of Set 3 | jalalabad
# Processing Record 32 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 33 of Set 3 | kristiinankaupunki
# Processing Record 34 of Set 3 | bourail
# Processing Record 35 of Set 3 | rawannawi
# City not found. Skipping...
# Processing Record 36 of Set 3 | rayadrug
# Processing Record 37 of Set 3 | arroyo
# Processing Record 38 of Set 3 | peleduy
# Processing Record 39 of Set 3 | hurghada
# Processing Record 40 of Set 3 | monte patria
# Processing Record 41 of Set 3 | tautira
# Processing Record 42 of Set 3 | sovetskiy
# Processing Record 43 of Set 3 | barrow
# Processing Record 44 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 45 of Set 3 | saskylakh
# Processing Record 46 of Set 3 | port macquarie
# Processing Record 47 of Set 3 | karratha
# Processing Record 48 of Set 3 | choucheng
# City not found. Skipping...
# Processing Record 49 of Set 3 | mehamn
# Processing Record 50 of Set 3 | vestmannaeyjar
# Processing Record 1 of Set 4 | kapaa
# Processing Record 2 of Set 4 | talcahuano
# Processing Record 3 of Set 4 | port keats
# Processing Record 4 of Set 4 | hermanus
# Processing Record 5 of Set 4 | westport
# Processing Record 6 of Set 4 | sechura
# Processing Record 7 of Set 4 | casablanca
# Processing Record 8 of Set 4 | ust-tsilma
# Processing Record 9 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 10 of Set 4 | constitucion
# Processing Record 11 of Set 4 | aden
# Processing Record 12 of Set 4 | sri aman
# Processing Record 13 of Set 4 | sur
# Processing Record 14 of Set 4 | leticia
# Processing Record 15 of Set 4 | sturgis
# Processing Record 16 of Set 4 | tooele
# Processing Record 17 of Set 4 | kaitangata
# Processing Record 18 of Set 4 | vila velha
# Processing Record 19 of Set 4 | yantzaza
# Processing Record 20 of Set 4 | noratus
# Processing Record 21 of Set 4 | faanui
# Processing Record 22 of Set 4 | puerto ayora
# Processing Record 23 of Set 4 | khash
# Processing Record 24 of Set 4 | zhigansk
# Processing Record 25 of Set 4 | wagar
# Processing Record 26 of Set 4 | anadyr
# Processing Record 27 of Set 4 | parys
# Processing Record 28 of Set 4 | zelenoborsk
# Processing Record 29 of Set 4 | laurentides
# Processing Record 30 of Set 4 | georgetown
# Processing Record 31 of Set 4 | ginir
# Processing Record 32 of Set 4 | isangel
# Processing Record 33 of Set 4 | kahului
# Processing Record 34 of Set 4 | kemin
# Processing Record 35 of Set 4 | carnarvon
# Processing Record 36 of Set 4 | caxito
# Processing Record 37 of Set 4 | oranjemund
# Processing Record 38 of Set 4 | itarema
# Processing Record 39 of Set 4 | huilong
# Processing Record 40 of Set 4 | zverinogolovskoye
# Processing Record 41 of Set 4 | salalah
# Processing Record 42 of Set 4 | turan
# Processing Record 43 of Set 4 | pervomayskoye
# Processing Record 44 of Set 4 | souillac
# Processing Record 45 of Set 4 | jales
# Processing Record 46 of Set 4 | kununurra
# Processing Record 47 of Set 4 | richards bay
# Processing Record 48 of Set 4 | geraldton
# Processing Record 49 of Set 4 | north bend
# Processing Record 50 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 1 of Set 5 | lorengau
# Processing Record 2 of Set 5 | sept-iles
# Processing Record 3 of Set 5 | mishkino
# Processing Record 4 of Set 5 | zheleznodorozhnyy
# Processing Record 5 of Set 5 | san juan de uraba
# Processing Record 6 of Set 5 | viligili
# City not found. Skipping...
# Processing Record 7 of Set 5 | codrington
# Processing Record 8 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 9 of Set 5 | katsuura
# Processing Record 10 of Set 5 | fortuna
# Processing Record 11 of Set 5 | rawah
# Processing Record 12 of Set 5 | novyy rogachik
# Processing Record 13 of Set 5 | sal rei
# Processing Record 14 of Set 5 | gaoual
# Processing Record 15 of Set 5 | ekhabi
# Processing Record 16 of Set 5 | altstatten
# Processing Record 17 of Set 5 | esperance
# Processing Record 18 of Set 5 | tidore
# City not found. Skipping...
# Processing Record 19 of Set 5 | belushya guba
# City not found. Skipping...
# Processing Record 20 of Set 5 | akureyri
# Processing Record 21 of Set 5 | lompoc
# Processing Record 22 of Set 5 | manbij
# Processing Record 23 of Set 5 | moose factory
# Processing Record 24 of Set 5 | basco
# Processing Record 25 of Set 5 | havoysund
# Processing Record 26 of Set 5 | hong gai
# Processing Record 27 of Set 5 | vredendal
# Processing Record 28 of Set 5 | do gonbadan
# Processing Record 29 of Set 5 | yirol
# City not found. Skipping...
# Processing Record 30 of Set 5 | mount gambier
# Processing Record 31 of Set 5 | coihaique
# Processing Record 32 of Set 5 | kichera
# Processing Record 33 of Set 5 | langsa
# Processing Record 34 of Set 5 | sanand
# Processing Record 35 of Set 5 | norman wells
# Processing Record 36 of Set 5 | bambous virieux
# Processing Record 37 of Set 5 | mandalgovi
# Processing Record 38 of Set 5 | kungurtug
# Processing Record 39 of Set 5 | stephenville
# Processing Record 40 of Set 5 | tucupita
# Processing Record 41 of Set 5 | vanimo
# Processing Record 42 of Set 5 | tabou
# Processing Record 43 of Set 5 | hualmay
# Processing Record 44 of Set 5 | nelipyno
# Processing Record 45 of Set 5 | san cristobal
# Processing Record 46 of Set 5 | opuwo
# Processing Record 47 of Set 5 | chokurdakh
# Processing Record 48 of Set 5 | cumberland
# Processing Record 49 of Set 5 | ostrovnoy
# Processing Record 50 of Set 5 | balakhta
# Processing Record 1 of Set 6 | kuznechnoye
# Processing Record 2 of Set 6 | flinders
# Processing Record 3 of Set 6 | myitkyina
# Processing Record 4 of Set 6 | chicama
# Processing Record 5 of Set 6 | launceston
# Processing Record 6 of Set 6 | turukhansk
# Processing Record 7 of Set 6 | morshansk
# Processing Record 8 of Set 6 | sentyabrskiy
# City not found. Skipping...
# Processing Record 9 of Set 6 | tiarei
# Processing Record 10 of Set 6 | babanusah
# City not found. Skipping...
# Processing Record 11 of Set 6 | petropavl
# Processing Record 12 of Set 6 | misrikh
# Processing Record 13 of Set 6 | havre-saint-pierre
# Processing Record 14 of Set 6 | severo-kurilsk
# Processing Record 15 of Set 6 | dingli
# Processing Record 16 of Set 6 | branford
# Processing Record 17 of Set 6 | fauske
# Processing Record 18 of Set 6 | parsons
# Processing Record 19 of Set 6 | bilibino
# Processing Record 20 of Set 6 | hervey bay
# Processing Record 21 of Set 6 | nanortalik
# Processing Record 22 of Set 6 | pudozh
# Processing Record 23 of Set 6 | duma
# Processing Record 24 of Set 6 | okhotsk
# Processing Record 25 of Set 6 | springdale
# Processing Record 26 of Set 6 | jatibonico
# Processing Record 27 of Set 6 | avera
# Processing Record 28 of Set 6 | aconibe
# Processing Record 29 of Set 6 | malakal
# Processing Record 30 of Set 6 | kochi
# Processing Record 31 of Set 6 | san jose de buan
# Processing Record 32 of Set 6 | bethel
# Processing Record 33 of Set 6 | komsomolskiy
# Processing Record 34 of Set 6 | kanker
# Processing Record 35 of Set 6 | shubarkuduk
# Processing Record 36 of Set 6 | odessa
# Processing Record 37 of Set 6 | surt
# Processing Record 38 of Set 6 | nome
# Processing Record 39 of Set 6 | abu samrah
# Processing Record 40 of Set 6 | cabo san lucas
# Processing Record 41 of Set 6 | salinas
# Processing Record 42 of Set 6 | andenes
# Processing Record 43 of Set 6 | harlingen
# Processing Record 44 of Set 6 | butterworth
# Processing Record 45 of Set 6 | kangaatsiaq
# Processing Record 46 of Set 6 | aflu
# City not found. Skipping...
# Processing Record 47 of Set 6 | namatanai
# Processing Record 48 of Set 6 | longyearbyen
# Processing Record 49 of Set 6 | aklavik
# Processing Record 50 of Set 6 | ilembo
# Processing Record 1 of Set 7 | lavrentiya
# Processing Record 2 of Set 7 | shelburne
# Processing Record 3 of Set 7 | acheng
# Processing Record 4 of Set 7 | lavumisa
# Processing Record 5 of Set 7 | buala
# Processing Record 6 of Set 7 | korcula
# Processing Record 7 of Set 7 | ilulissat
# Processing Record 8 of Set 7 | pryazha
# Processing Record 9 of Set 7 | moron
# Processing Record 10 of Set 7 | haines junction
# Processing Record 11 of Set 7 | orlik
# Processing Record 12 of Set 7 | rio grande
# Processing Record 13 of Set 7 | goderich
# Processing Record 14 of Set 7 | nushki
# Processing Record 15 of Set 7 | banamba
# Processing Record 16 of Set 7 | tuatapere
# Processing Record 17 of Set 7 | santa lucia
# Processing Record 18 of Set 7 | turbat
# Processing Record 19 of Set 7 | scottsburgh
# City not found. Skipping...
# Processing Record 20 of Set 7 | pochutla
# Processing Record 21 of Set 7 | altay
# Processing Record 22 of Set 7 | ketchikan
# Processing Record 23 of Set 7 | querendaro
# Processing Record 24 of Set 7 | mokhsogollokh
# Processing Record 25 of Set 7 | mishelevka
# Processing Record 26 of Set 7 | chara
# Processing Record 27 of Set 7 | saint-francois
# Processing Record 28 of Set 7 | ahipara
# Processing Record 29 of Set 7 | praia da vitoria
# Processing Record 30 of Set 7 | alta floresta
# Processing Record 31 of Set 7 | port elizabeth
# Processing Record 32 of Set 7 | lambarene
# Processing Record 33 of Set 7 | sarahan
# Processing Record 34 of Set 7 | manzhouli
# Processing Record 35 of Set 7 | saint-denis
# Processing Record 36 of Set 7 | labytnangi
# Processing Record 37 of Set 7 | puerto carreno
# Processing Record 38 of Set 7 | palmer
# Processing Record 39 of Set 7 | luwuk
# Processing Record 40 of Set 7 | touros
# Processing Record 41 of Set 7 | faya
# Processing Record 42 of Set 7 | xixiang
# Processing Record 43 of Set 7 | sayyan
# Processing Record 44 of Set 7 | diu
# Processing Record 45 of Set 7 | miranda
# Processing Record 46 of Set 7 | brae
# Processing Record 47 of Set 7 | pouembout
# Processing Record 48 of Set 7 | muhos
# Processing Record 49 of Set 7 | petropavlovsk-kamchatskiy
# Processing Record 50 of Set 7 | kyrylivka
# Processing Record 1 of Set 8 | karamea
# City not found. Skipping...
# Processing Record 2 of Set 8 | buluang
# Processing Record 3 of Set 8 | san patricio
# Processing Record 4 of Set 8 | palabuhanratu
# City not found. Skipping...
# Processing Record 5 of Set 8 | logon
# Processing Record 6 of Set 8 | dingle
# Processing Record 7 of Set 8 | uray
# Processing Record 8 of Set 8 | inuvik
# Processing Record 9 of Set 8 | grand gaube
# Processing Record 10 of Set 8 | ahuimanu
# Processing Record 11 of Set 8 | kuloy
# Processing Record 12 of Set 8 | neya
# Processing Record 13 of Set 8 | bolsheustikinskoye
# City not found. Skipping...
# Processing Record 14 of Set 8 | cairns
# Processing Record 15 of Set 8 | meyungs
# City not found. Skipping...
# Processing Record 16 of Set 8 | lanzhou
# Processing Record 17 of Set 8 | husavik
# Processing Record 18 of Set 8 | thompson
# Processing Record 19 of Set 8 | masaurhi
# Processing Record 20 of Set 8 | pisco
# Processing Record 21 of Set 8 | damietta
# Processing Record 22 of Set 8 | leningradskiy
# Processing Record 23 of Set 8 | hamilton
# Processing Record 24 of Set 8 | moreira sales
# Processing Record 25 of Set 8 | sasni
# Processing Record 26 of Set 8 | takoradi
# Processing Record 27 of Set 8 | port hawkesbury
# Processing Record 28 of Set 8 | jiddah
# City not found. Skipping...
# Processing Record 29 of Set 8 | kodiak
# Processing Record 30 of Set 8 | bathsheba
# Processing Record 31 of Set 8 | batsfjord
# Processing Record 32 of Set 8 | asfi
# Processing Record 33 of Set 8 | mbuji-mayi
# Processing Record 34 of Set 8 | yichang
# Processing Record 35 of Set 8 | prince rupert
# Processing Record 36 of Set 8 | porto tolle
# Processing Record 37 of Set 8 | ginda
# Processing Record 38 of Set 8 | eydhafushi
# Processing Record 39 of Set 8 | ixtapa
# Processing Record 40 of Set 8 | albacete
# Processing Record 41 of Set 8 | umm lajj
# Processing Record 42 of Set 8 | steinbach
# Processing Record 43 of Set 8 | madimba
# Processing Record 44 of Set 8 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 45 of Set 8 | walvis bay
# Processing Record 46 of Set 8 | mahanje
# Processing Record 47 of Set 8 | port blair
# Processing Record 48 of Set 8 | khani
# Processing Record 49 of Set 8 | sain alto
# Processing Record 50 of Set 8 | camacari
# Processing Record 1 of Set 9 | urfa
# City not found. Skipping...
# Processing Record 2 of Set 9 | berlevag
# Processing Record 3 of Set 9 | mozarlandia
# Processing Record 4 of Set 9 | jos
# Processing Record 5 of Set 9 | pacific grove
# Processing Record 6 of Set 9 | khonuu
# City not found. Skipping...
# Processing Record 7 of Set 9 | dire
# Processing Record 8 of Set 9 | springfield
# Processing Record 9 of Set 9 | lichuan
# Processing Record 10 of Set 9 | te anau
# Processing Record 11 of Set 9 | octeville
# Processing Record 12 of Set 9 | bumba
# Processing Record 13 of Set 9 | karauzyak
# City not found. Skipping...
# Processing Record 14 of Set 9 | port hedland
# Processing Record 15 of Set 9 | kracheh
# City not found. Skipping...
# Processing Record 16 of Set 9 | kavieng
# Processing Record 17 of Set 9 | erzin
# Processing Record 18 of Set 9 | dickinson
# Processing Record 19 of Set 9 | burnie
# Processing Record 20 of Set 9 | acapulco
# Processing Record 21 of Set 9 | mujiayingzi
# Processing Record 22 of Set 9 | cobija
# Processing Record 23 of Set 9 | zarautz
# Processing Record 24 of Set 9 | namibe
# Processing Record 25 of Set 9 | vanavara
# Processing Record 26 of Set 9 | jalu
# Processing Record 27 of Set 9 | montlucon
# Processing Record 28 of Set 9 | kavaratti
# Processing Record 29 of Set 9 | mendahara
# City not found. Skipping...
# Processing Record 30 of Set 9 | taitung
# Processing Record 31 of Set 9 | deder
# Processing Record 32 of Set 9 | calvinia
# Processing Record 33 of Set 9 | abnub
# Processing Record 34 of Set 9 | sobolevo
# Processing Record 35 of Set 9 | coquimbo
# Processing Record 36 of Set 9 | santa rosa
# Processing Record 37 of Set 9 | eureka
# Processing Record 38 of Set 9 | sola
# Processing Record 39 of Set 9 | periyanayakkanpalaiyam
# Processing Record 40 of Set 9 | alice springs
# Processing Record 41 of Set 9 | utiel
# Processing Record 42 of Set 9 | severodvinsk
# Processing Record 43 of Set 9 | veraval
# Processing Record 44 of Set 9 | barcelona
# Processing Record 45 of Set 9 | lerwick
# Processing Record 46 of Set 9 | chapais
# Processing Record 47 of Set 9 | karema
# Processing Record 48 of Set 9 | ponta delgada
# Processing Record 49 of Set 9 | hasaki
# Processing Record 50 of Set 9 | pak phanang
# Processing Record 1 of Set 10 | poum
# Processing Record 2 of Set 10 | barcelos
# Processing Record 3 of Set 10 | ternate
# Processing Record 4 of Set 10 | zhezkazgan
# Processing Record 5 of Set 10 | sampit
# Processing Record 6 of Set 10 | amparai
# City not found. Skipping...
# Processing Record 7 of Set 10 | marcona
# City not found. Skipping...
# Processing Record 8 of Set 10 | gilgit
# Processing Record 9 of Set 10 | marapanim
# Processing Record 10 of Set 10 | markivka
# Processing Record 11 of Set 10 | vao
# Processing Record 12 of Set 10 | hofn
# Processing Record 13 of Set 10 | sarakhs
# Processing Record 14 of Set 10 | winnipeg
# Processing Record 15 of Set 10 | kedrovyy
# Processing Record 16 of Set 10 | tommot
# Processing Record 17 of Set 10 | kalengwa
# Processing Record 18 of Set 10 | carauari
# Processing Record 19 of Set 10 | kegayli
# City not found. Skipping...
# Processing Record 20 of Set 10 | blackpool
# Processing Record 21 of Set 10 | djambala
# Processing Record 22 of Set 10 | longlac
# City not found. Skipping...
# Processing Record 23 of Set 10 | akita
# Processing Record 24 of Set 10 | loandjili
# Processing Record 25 of Set 10 | ambilobe
# Processing Record 26 of Set 10 | ibra
# Processing Record 27 of Set 10 | karkal
# Processing Record 28 of Set 10 | ulaanbaatar
# Processing Record 29 of Set 10 | kikwit
# Processing Record 30 of Set 10 | mersin
# Processing Record 31 of Set 10 | dano
# Processing Record 32 of Set 10 | porto novo
# Processing Record 33 of Set 10 | inyonga
# Processing Record 34 of Set 10 | praya
# Processing Record 35 of Set 10 | camana
# Processing Record 36 of Set 10 | mayumba
# Processing Record 37 of Set 10 | acarau
# Processing Record 38 of Set 10 | high level
# Processing Record 39 of Set 10 | cockburn town
# Processing Record 40 of Set 10 | campbell river
# Processing Record 41 of Set 10 | banda aceh
# Processing Record 42 of Set 10 | doha
# Processing Record 43 of Set 10 | mandan
# Processing Record 44 of Set 10 | la ronge
# Processing Record 45 of Set 10 | miandrivazo
# Processing Record 46 of Set 10 | mitzic
# Processing Record 47 of Set 10 | viedma
# Processing Record 48 of Set 10 | port-gentil
# Processing Record 49 of Set 10 | esik
# Processing Record 50 of Set 10 | chumikan
# Processing Record 1 of Set 11 | afgoye
# City not found. Skipping...
# Processing Record 2 of Set 11 | chulman
# Processing Record 3 of Set 11 | diffa
# Processing Record 4 of Set 11 | medea
# Processing Record 5 of Set 11 | oussouye
# Processing Record 6 of Set 11 | bandrele
# Processing Record 7 of Set 11 | omutinskoye
# City not found. Skipping...
# Processing Record 8 of Set 11 | dosso
# Processing Record 9 of Set 11 | yangambi
# Processing Record 10 of Set 11 | benidorm
# Processing Record 11 of Set 11 | arman
# Processing Record 12 of Set 11 | baculin
# Processing Record 13 of Set 11 | bur gabo
# City not found. Skipping...
# Processing Record 14 of Set 11 | ugoofaaru
# Processing Record 15 of Set 11 | marshall
# Processing Record 16 of Set 11 | camapua
# Processing Record 17 of Set 11 | scarborough
# Processing Record 18 of Set 11 | makakilo city
# Processing Record 19 of Set 11 | galiwinku
# City not found. Skipping...
# Processing Record 20 of Set 11 | san luis
# Processing Record 21 of Set 11 | cap malheureux
# Processing Record 22 of Set 11 | iqaluit
# Processing Record 23 of Set 11 | asosa
# Processing Record 24 of Set 11 | adre
# Processing Record 25 of Set 11 | jacareacanga
# Processing Record 26 of Set 11 | abbotsford
# Processing Record 27 of Set 11 | tabuk
# Processing Record 28 of Set 11 | jijiga
# Processing Record 29 of Set 11 | imeni babushkina
# Processing Record 30 of Set 11 | staroutkinsk
# Processing Record 31 of Set 11 | mikhaylovka
# Processing Record 32 of Set 11 | marshfield
# Processing Record 33 of Set 11 | saint-joseph
# Processing Record 34 of Set 11 | truth or consequences
# Processing Record 35 of Set 11 | lewistown
# Processing Record 36 of Set 11 | sao gabriel da cachoeira
# Processing Record 37 of Set 11 | matagami
# Processing Record 38 of Set 11 | lyuban
# Processing Record 39 of Set 11 | leh
# Processing Record 40 of Set 11 | duzici
# City not found. Skipping...
# Processing Record 41 of Set 11 | palasa
# Processing Record 42 of Set 11 | beloha
# Processing Record 43 of Set 11 | samusu
# City not found. Skipping...
# Processing Record 44 of Set 11 | kayalpattinam
# Processing Record 45 of Set 11 | police
# Processing Record 46 of Set 11 | fukuma
# Processing Record 47 of Set 11 | nedjo
# Processing Record 48 of Set 11 | tall kayf
# Processing Record 49 of Set 11 | kupino
# Processing Record 50 of Set 11 | tabialan
# City not found. Skipping...
# Processing Record 1 of Set 12 | teahupoo
# Processing Record 2 of Set 12 | lebowakgomo
# Processing Record 3 of Set 12 | waingapu
# Processing Record 4 of Set 12 | pertuis
# Processing Record 5 of Set 12 | puerto rondon
# Processing Record 6 of Set 12 | skeldon
# Processing Record 7 of Set 12 | anloga
# Processing Record 8 of Set 12 | taltal
# Processing Record 9 of Set 12 | urusha
# Processing Record 10 of Set 12 | orbetello
# Processing Record 11 of Set 12 | general roca
# Processing Record 12 of Set 12 | catuday
# Processing Record 13 of Set 12 | tura
# Processing Record 14 of Set 12 | guadalupe y calvo
# Processing Record 15 of Set 12 | otane
# Processing Record 16 of Set 12 | vostok
# Processing Record 17 of Set 12 | matara
# Processing Record 18 of Set 12 | greenwood
# Processing Record 19 of Set 12 | angoche
# Processing Record 20 of Set 12 | saint-pierre
# Processing Record 21 of Set 12 | zyryanka
# Processing Record 22 of Set 12 | salta
# Processing Record 23 of Set 12 | bulgan
# Processing Record 24 of Set 12 | jizan
# Processing Record 25 of Set 12 | kieta
# Processing Record 26 of Set 12 | belyy yar
# Processing Record 27 of Set 12 | resen
# Processing Record 28 of Set 12 | cidreira
# Processing Record 29 of Set 12 | ndende
# Processing Record 30 of Set 12 | la rioja
# Processing Record 31 of Set 12 | savinka
# Processing Record 32 of Set 12 | batagay-alyta
# Processing Record 33 of Set 12 | xining
# Processing Record 34 of Set 12 | coihueco
# Processing Record 35 of Set 12 | palana
# Processing Record 36 of Set 12 | jumla
# Processing Record 37 of Set 12 | parry sound
# Processing Record 38 of Set 12 | erzurum
# Processing Record 39 of Set 12 | bambanglipuro
# Processing Record 40 of Set 12 | lesnoy
# Processing Record 41 of Set 12 | sorong
# Processing Record 42 of Set 12 | tarhunah
# City not found. Skipping...
# Processing Record 43 of Set 12 | ambovombe
# Processing Record 44 of Set 12 | comodoro rivadavia
# Processing Record 45 of Set 12 | havelock
# Processing Record 46 of Set 12 | tumaco
# Processing Record 47 of Set 12 | sitka
# Processing Record 48 of Set 12 | kuche
# City not found. Skipping...
# Processing Record 49 of Set 12 | kapan
# Processing Record 50 of Set 12 | dieppe
# Processing Record 1 of Set 13 | korla
# Processing Record 2 of Set 13 | russell
# Processing Record 3 of Set 13 | tchibanga
# Processing Record 4 of Set 13 | mahibadhoo
# Processing Record 5 of Set 13 | datong
# Processing Record 6 of Set 13 | broken hill
# Processing Record 7 of Set 13 | tubruq
# City not found. Skipping...
# Processing Record 8 of Set 13 | oskarshamn
# Processing Record 9 of Set 13 | hami
# Processing Record 10 of Set 13 | saleaula
# City not found. Skipping...
# Processing Record 11 of Set 13 | aksarka
# Processing Record 12 of Set 13 | tavira
# Processing Record 13 of Set 13 | cintalapa
# Processing Record 14 of Set 13 | phan rang
# City not found. Skipping...
# Processing Record 15 of Set 13 | yilan
# Processing Record 16 of Set 13 | eenhana
# Processing Record 17 of Set 13 | qasigiannguit
# Processing Record 18 of Set 13 | sorvag
# City not found. Skipping...
# Processing Record 19 of Set 13 | macas
# Processing Record 20 of Set 13 | santa cruz
# Processing Record 21 of Set 13 | yagodnoye
# Processing Record 22 of Set 13 | caravelas
# Processing Record 23 of Set 13 | tarudant
# City not found. Skipping...
# Processing Record 24 of Set 13 | aswan
# Processing Record 25 of Set 13 | tuli
# Processing Record 26 of Set 13 | linxia
# Processing Record 27 of Set 13 | liku
# Processing Record 28 of Set 13 | bati
# Processing Record 29 of Set 13 | belaya gora
# Processing Record 30 of Set 13 | bagdarin
# Processing Record 31 of Set 13 | college
# Processing Record 32 of Set 13 | chiredzi
# Processing Record 33 of Set 13 | qaqortoq
# Processing Record 34 of Set 13 | teguldet
# Processing Record 35 of Set 13 | boysun
# Processing Record 36 of Set 13 | churapcha
# Processing Record 37 of Set 13 | kismayo
# Processing Record 38 of Set 13 | puerto narino
# Processing Record 39 of Set 13 | mount pleasant
# Processing Record 40 of Set 13 | port augusta
# Processing Record 41 of Set 13 | tapaua
# City not found. Skipping...
# Processing Record 42 of Set 13 | zachagansk
# City not found. Skipping...
# Processing Record 43 of Set 13 | vedaranniyam
# City not found. Skipping...
# Processing Record 44 of Set 13 | clyde river
# Processing Record 45 of Set 13 | krasnoselkup
# Processing Record 46 of Set 13 | chenghai
# Processing Record 47 of Set 13 | odweyne
# Processing Record 48 of Set 13 | hirara
# Processing Record 49 of Set 13 | ferai
# City not found. Skipping...
# Processing Record 50 of Set 13 | mezen
# Processing Record 1 of Set 14 | ta khmau
# Processing Record 2 of Set 14 | crown point
# Processing Record 3 of Set 14 | riyadh
# Processing Record 4 of Set 14 | bajil
# Processing Record 5 of Set 14 | severiano melo
# Processing Record 6 of Set 14 | palkino
# Processing Record 7 of Set 14 | itaberaba
# Processing Record 8 of Set 14 | jaleswar
# Processing Record 9 of Set 14 | itupeva
# Processing Record 10 of Set 14 | japura
# Processing Record 11 of Set 14 | kedougou
# Processing Record 12 of Set 14 | pangnirtung
# Processing Record 13 of Set 14 | eberswalde
# Processing Record 14 of Set 14 | paamiut
# Processing Record 15 of Set 14 | sambava
# Processing Record 16 of Set 14 | moscow
# Processing Record 17 of Set 14 | hadejia
# Processing Record 18 of Set 14 | baley
# Processing Record 19 of Set 14 | lapeer
# Processing Record 20 of Set 14 | denia
# Processing Record 21 of Set 14 | slave lake
# Processing Record 22 of Set 14 | verin
# Processing Record 23 of Set 14 | rafai
# Processing Record 24 of Set 14 | cururupu
# Processing Record 25 of Set 14 | sangar
# Processing Record 26 of Set 14 | filingue
# Processing Record 27 of Set 14 | mpulungu
# Processing Record 28 of Set 14 | zhaozhou
# Processing Record 29 of Set 14 | manggar
# Processing Record 30 of Set 14 | melur
# Processing Record 31 of Set 14 | carlsbad
# Processing Record 32 of Set 14 | port shepstone
# Processing Record 33 of Set 14 | obihiro
# Processing Record 34 of Set 14 | mangrol
# Processing Record 35 of Set 14 | athabasca
# Processing Record 36 of Set 14 | seminole
# Processing Record 37 of Set 14 | sydney
# Processing Record 38 of Set 14 | beringovskiy
# Processing Record 39 of Set 14 | carupano
# Processing Record 40 of Set 14 | marawi
# Processing Record 41 of Set 14 | the valley
# Processing Record 42 of Set 14 | vammala
# Processing Record 43 of Set 14 | kotelnikovo
# Processing Record 44 of Set 14 | hit
# Processing Record 45 of Set 14 | viransehir
# Processing Record 46 of Set 14 | laibin
# Processing Record 47 of Set 14 | kihei
# Processing Record 48 of Set 14 | nguiu
# City not found. Skipping...
# Processing Record 49 of Set 14 | novosineglazovskiy
# Processing Record 50 of Set 14 | vila franca do campo
# Processing Record 1 of Set 15 | akyab
# Processing Record 2 of Set 15 | saint anthony
# Processing Record 3 of Set 15 | hovd
# Processing Record 4 of Set 15 | rundu
# Processing Record 5 of Set 15 | yumen
# Processing Record 6 of Set 15 | marau
# Processing Record 7 of Set 15 | cayenne
# Processing Record 8 of Set 15 | iracoubo
# Processing Record 9 of Set 15 | chingirlau
# Processing Record 10 of Set 15 | skagastrond
# City not found. Skipping...
# Processing Record 11 of Set 15 | chuguyevka
# Processing Record 12 of Set 15 | sokolovyy
# Processing Record 13 of Set 15 | bartica
# Processing Record 14 of Set 15 | mchinji
# Processing Record 15 of Set 15 | adrar
# Processing Record 16 of Set 15 | lipari
# Processing Record 17 of Set 15 | azul
# Processing Record 18 of Set 15 | jujuy
# City not found. Skipping...
# Processing Record 19 of Set 15 | puerto madero
# Processing Record 20 of Set 15 | ipswich
# Processing Record 21 of Set 15 | hokitika
# Processing Record 22 of Set 15 | nazas
# Processing Record 23 of Set 15 | kiama
# Processing Record 24 of Set 15 | shenjiamen
# Processing Record 25 of Set 15 | plettenberg bay
# Processing Record 26 of Set 15 | laja
# Processing Record 27 of Set 15 | sudogda
# Processing Record 28 of Set 15 | kita
# Processing Record 29 of Set 15 | kulhudhuffushi
# Processing Record 30 of Set 15 | kazalinsk
# City not found. Skipping...
# Processing Record 31 of Set 15 | yabrud
# Processing Record 32 of Set 15 | seoul
# Processing Record 33 of Set 15 | alyangula
# Processing Record 34 of Set 15 | lugovoy
# Processing Record 35 of Set 15 | bauta
# Processing Record 36 of Set 15 | bubaque
# Processing Record 37 of Set 15 | koscian
# Processing Record 38 of Set 15 | el dorado
# Processing Record 39 of Set 15 | noumea
# Processing Record 40 of Set 15 | mudgee
# Processing Record 41 of Set 15 | mpika
# Processing Record 42 of Set 15 | twentynine palms
# Processing Record 43 of Set 15 | kotelnich
# Processing Record 44 of Set 15 | beeville
# Processing Record 45 of Set 15 | tutoia
# Processing Record 46 of Set 15 | birao
# Processing Record 47 of Set 15 | ewa beach
# Processing Record 48 of Set 15 | maniitsoq
# Processing Record 49 of Set 15 | ruatoria
# City not found. Skipping...
# Processing Record 50 of Set 15 | san juan
# Processing Record 1 of Set 16 | anshun
# Processing Record 2 of Set 16 | olinda
# Processing Record 3 of Set 16 | muros
# Processing Record 4 of Set 16 | pietarsaari
# Processing Record 5 of Set 16 | maturin
# Processing Record 6 of Set 16 | otjimbingwe
# Processing Record 7 of Set 16 | dunedin
# Processing Record 8 of Set 16 | dzaoudzi
# Processing Record 9 of Set 16 | dwarka
# Processing Record 10 of Set 16 | pavagada
# Processing Record 11 of Set 16 | birjand
# Processing Record 12 of Set 16 | nizhnevartovsk
# Processing Record 13 of Set 16 | haibowan
# City not found. Skipping...
# Processing Record 14 of Set 16 | puerto escondido
# Processing Record 15 of Set 16 | oyon
# Processing Record 16 of Set 16 | kutum
# Processing Record 17 of Set 16 | byron bay
# Processing Record 18 of Set 16 | verkhnevilyuysk
# Processing Record 19 of Set 16 | batagay
# Processing Record 20 of Set 16 | maraa
# Processing Record 21 of Set 16 | plouzane
# Processing Record 22 of Set 16 | jubayl
# City not found. Skipping...
# Processing Record 23 of Set 16 | biskupiec
# Processing Record 24 of Set 16 | maku
# Processing Record 25 of Set 16 | mount isa
# Processing Record 26 of Set 16 | osoyoos
# Processing Record 27 of Set 16 | zhangjiakou
# Processing Record 28 of Set 16 | kloulklubed
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 713

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#          City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Vaini      TO -21.2000 -175.2000     75.36        83          20
# 1        Hilo      US  19.7297 -155.0900     79.25        74          40
# 2       Tiksi      RU  71.6872  128.8694     11.77        93         100
# 3        Chuy      UY -33.6971  -53.4616     62.65        63          81
# 4     Ushuaia      AR -54.8000  -68.3000     51.42        43          75
# 5    Bengkulu      ID  -3.8004  102.2655     74.73        90         100
# 6        Lebu      CL -37.6167  -73.6500     56.86        78          48
# 7  Butaritari      KI   3.0707  172.7902     81.36        74          44
# 8   Mahebourg      MU -20.4081   57.7000     75.49        73          75
# 9     Bintulu      MY   3.1667  113.0333     75.61        94          20
#
#    Wind Speed Current Description
# 0        5.75          few clouds
# 1        6.91    scattered clouds
# 2        5.95     overcast clouds
# 3       10.87       broken clouds
# 4       17.27       broken clouds
# 5        5.32          light rain
# 6        8.81    scattered clouds
# 7        9.33    scattered clouds
# 8        6.91          light rain
# 9        1.99          few clouds

# %%
output_data_file = "WeatherPy_Database.csv"
city_data_df.to_csv(output_data_file, index_label='City_ID')
